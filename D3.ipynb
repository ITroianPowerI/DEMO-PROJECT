# %% [markdown]
# # Модуль 1
# -------------------

# %%
import sklearn
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler

# Алгоритмы кластеризации
from sklearn.cluster import KMeans
from sklearn.cluster import MiniBatchKMeans
from sklearn.mixture import GaussianMixture


# %matplotlib inline

# %% [markdown]
# ### 1.1 Парсинг данных

# %%
df = pd.read_csv('data/train_2.csv', delimiter=';', low_memory=False)
df2 = pd.read_csv('data/train_1.csv', delimiter=';', low_memory=False)
df_merge = df.merge(df2, how='outer')

# %%
df_mer = df_merge.truncate(after=250000)

# %%
df_mer
# Out:
#                         ID  MM_IN_BANK  MM_W_CARD  AGE  GENDER
# 0       500000000000003702           5          5   35       2  \
# 1       500000000000003702           5          5   35       2
# 2       500000000000003702           5          5   35       2
# 3       500000000000003702           5          5   35       2
# 4       500000000000003702           5          5   35       2
# ...                    ...         ...        ...  ...     ...
# 249996  500000000000941823         128          1   37       2
# 249997  500000000000941823         128          1   37       2
# 249998  500000000000941823         128          1   37       2
# 249999  500000000000941823         128          1   37       2
# 250000  500000000000941823         128          1   37       2
#
#         EDUCATION_LEVEL  MARITAL_STATUS  DEPENDANT_CNT INCOME_MAIN_AMT
# 0                     3               3              0           87000  \
# 1                     3               3              0           87000
# 2                     3               3              0           87000
# 3                     3               3              0           87000
# 4                     3               3              0           87000
# ...                 ...             ...            ...             ...
# 249996               -1               1              0           82500
# 249997               -1               1              0           82500
# 249998               -1               1              0           82500
# 249999               -1               1              0           82500
# 250000               -1               1              0           82500
#
#         REG_CODE  PROD_TYPE           TRANS_DTTM  MCC_CODE SUM_TRANS
# 0            9.0          2  31.10.2021 11:30:06      5462       106  \
# 1            9.0          2  22.10.2021 10:46:13      5921    226,96
# 2            9.0          2  05.09.2021 10:02:10      4121       102
# 3            9.0          2  13.10.2021 21:24:47      5691     21642
# 4            9.0          2  27.10.2021 19:47:16      5399      4026
# ...          ...        ...                  ...       ...       ...
# 249996      47.0          1   01.09.2021 6:10:04      5541       178
# 249997      47.0          1  15.10.2021 19:00:10      5813       168
# 249998      47.0          1  17.08.2021 14:07:05      5441       299
# 249999      47.0          2  09.10.2021 19:16:01      5651       438
# 250000      47.0          1  30.10.2021 18:32:04      4131        25
#
#                                             LOCATION_NAME
# 0       BRECEL\9A 8-J VOZDUSHNOJ ARMII STR\VOLGOGRAD\4...
# 1       KRASNOE BELOE\14 8-J VOZDUSHNOJ ARMII STR\VOLG...
# 2       YM UBER\82 BLD 12 SADOVNICHESKAYA STR\MOSCOW\1...
# 3       WB\6 BLD 1 INDUSTRIALNYJ PARK KOLEDINO TER\POD...
# 4       YM*WILDBERRIES\MONEY.YANDEX.RU\MOSKVA\119021  ...
# ...                                                   ...
# 249996  RNAZSBN02-166\SAGITOVA, 1B\STERLITAMAK\453130 ...
# 249997  BEER BANK\D. 15 IVLEVA STR\STERLITAMAK\450000 ...
# 249998  IP MATSUK L.N.\UL. MIRA 1/B\STERLITAMAK\453109...
# 249999  LLC MAXIMA GROUP\KHUDAYBERDINA, 120\STERLITAMA...
# 250000   TRANSPORT RB\9 KRUPSKOJ STR\UFA\452000    RUSRUS
#
# [250001 rows x 15 columns]

# %%
df_mer["INCOME_MAIN_AMT"] = df_mer["INCOME_MAIN_AMT"].astype(str).str.replace(",", ".").astype(float)
#Приводим данный атрибут в числовой формат(в вещественные числа), в данном методе используем replace(заменяет запятую на точку) 
#и astype(переводит в вещественный тип данных)

# %%
df_mer = df_mer[['AGE', 'GENDER', 'EDUCATION_LEVEL', 'MARITAL_STATUS', 'INCOME_MAIN_AMT', 'REG_CODE']]

# %%
plt.figure(figsize=(23, 15))
sns.heatmap(df_mer.corr(), annot = True, vmin=-1, vmax=1,cmap= 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# На корреляционной карте выше видно, что довольно сильно коррелируют между собой атрибуты:<br>
# MATIRIAL_STATUS и EDUCATION_LEVEL<br>
# EDUCATION_LEVEL и DEPENDANT_CNT<br>
# MM_W_CARD и MM_IN_BANK<br>
# ID и MM_IN_BANK<br>

# %% [markdown]
# ### 1.3 Предварительная обработка данных

# %%
df_mer.dropna(inplace=True)
df_mer.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_24244\1540549248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mer.dropna(inplace=True)

# %%
#Вывод коробчатых диаграм в цикле только по числовым атриубтам
for col in df_mer.select_dtypes(exclude=["object", "datetime64[ns]"]).columns:
    #построение фигуры
    plt.figure()
    #Заголовк
    plt.title(col)
    #Вывод диаграммы
    plt.boxplot(df_mer[col])
    plt.show()

# %%
#Вывод коробчатых диаграм в цикле только по числовым атриубтам
for col in df_mer.select_dtypes(exclude=["object", "datetime64[ns]"]).columns:
    Q1 = df_mer[col].quantile(0.25)
    Q3 = df_mer[col].quantile(0.75)
    IQR = Q3 - Q1    #IQR is interquartile range. 

    filter = (df_mer[col] >= Q1 - 1.5 * IQR) & (df_mer[col] <= Q3 + 1.5 *IQR)
    df_mer = df_mer.loc[filter]

# %%
#Вывод коробчатых диаграм в цикле только по числовым атриубтам
for col in df_mer.select_dtypes(exclude=["object", "datetime64[ns]"]).columns:
    #построение фигуры
    plt.figure()
    #Заголовк
    plt.title(col)
    #Вывод диаграммы
    plt.boxplot(df_mer[col])
    plt.show()

# %% [markdown]
# У атрибута 'INCOME_MAIN_AMT' можно увидеть небольшое отклонение от того что было, но это уже приемлимо

# %% [markdown]
# ### 1.4 Формирование дополнительных атрибутов

# %% [markdown]
# Перевод из рублей в евро и юани

# %%
df_mer['INCOME_MAIN_AMT_EUR'] = df_mer['INCOME_MAIN_AMT'].apply(lambda x: x / 80)

# %%
df_mer['INCOME_MAIN_AMT_CNY'] = df_mer['INCOME_MAIN_AMT'].apply(lambda x: x / 11)

# %%
df_mer
# Out:
#         AGE  GENDER  EDUCATION_LEVEL  MARITAL_STATUS  INCOME_MAIN_AMT
# 0        35       2                3               3          87000.0  \
# 1        35       2                3               3          87000.0
# 2        35       2                3               3          87000.0
# 3        35       2                3               3          87000.0
# 4        35       2                3               3          87000.0
# ...     ...     ...              ...             ...              ...
# 206376   37       2               -1               1          82500.0
# 206377   37       2               -1               1          82500.0
# 206378   37       2               -1               1          82500.0
# 206379   37       2               -1               1          82500.0
# 206380   37       2               -1               1          82500.0
#
#         REG_CODE  INCOME_MAIN_AMT_EUR  INCOME_MAIN_AMT_CNY
# 0            9.0              1087.50          7909.090909
# 1            9.0              1087.50          7909.090909
# 2            9.0              1087.50          7909.090909
# 3            9.0              1087.50          7909.090909
# 4            9.0              1087.50          7909.090909
# ...          ...                  ...                  ...
# 206376      47.0              1031.25          7500.000000
# 206377      47.0              1031.25          7500.000000
# 206378      47.0              1031.25          7500.000000
# 206379      47.0              1031.25          7500.000000
# 206380      47.0              1031.25          7500.000000
#
# [121465 rows x 8 columns]

# %% [markdown]
# Был создан дополнительный атрибут, который демонстрирует курс рубля к юаням, а так же и к евро. Т.к. было бы интересно посмотреть сколько это бы стоило по другому курсу валют.

# %% [markdown]
# ### 1.5 Кластеризация

# %% [markdown]
# Подготовка данных
# Отдельно возьму атрибуты, которые буду визуализировать

# %%
#Помещу их в переменную X
X = df_mer[["AGE", "GENDER", "EDUCATION_LEVEL"]]

# %% [markdown]
# Я выбрал эти атрибуты, так как в зависимости от региона и категории товара (продовца) стоимость покупок будет разной и я считаю, что этих атрибутов будет достаточно что бы модель не имела проблем с переобучением и недообучением

# %% [markdown]
# #### MinMaxScaler
# Преобразование характеристик путем масштабирования каждой характеристики в заданном диапазоне. Этот оценщик масштабирует и переводит каждый признак в отдельности таким образом,чтобы он находился в заданном диапазоне на обучающем множестве,например,между нулем и единицей.

# %%
#обьявляю MinMaxScaler
scaler = MinMaxScaler()
#преобразую данные
X = scaler.fit_transform(X)

# %% [markdown]
# #### PCA
# Метод главных компонент — один из основных способов уменьшить размерность данных, потеряв наименьшее количество информации.

# %%
#Обьявляю метод главных компонент
pca = PCA(n_components=2)
#Применяю его на данных
X = pca.fit_transform(X)

# %% [markdown]
# #### Функция визуализации
# Отдельно вынесу функцию для визуализации

# %%
#Функция для визуализации распределения 
def viz(prediction):
    #Размер фигуры
    plt.figure(figsize=(12, 12))
    plt.subplot(224)
    #Выводить изображение буду при помощи scatter
    plt.scatter(X[:, 0], X[:, 1], c=prediction)
    plt.title("Unevenly Sized Blobs")
    #Вывод изображения
    plt.show()

# %% [markdown]
# #### Выбор алгоритмов (KMeans, MiniBatchKMeans, GaussianMixtures)
# Я решил взять алгоритмы KMeans, MiniBatchKMeans и GaussianMixtures, так как они идеально подходят для такого набора данных, они сочетают в себе скорость работы, а так же качество кластеризации

# %% [markdown]
# #### KMeans

# %%
#Настройка параметров
kmeans = KMeans(n_clusters=4, random_state=0).fit(X)
#Предсказание
kmpreds = kmeans.predict(X)
#Заношу кластеризированные метки в набор данных
df_mer["KMCLUSTS"] = kmpreds

#Применяю функцию описаную выше
viz(df_mer["KMCLUSTS"])
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #### MiniBatchKMeans

# %%
#Настройка параметров
kbmeans = MiniBatchKMeans(n_clusters=4, random_state=0, batch_size=4096)
#Заношу кластеризированные метки в набор данных
df_mer["KBCLUSTS"] = kbmeans.fit_predict(X)

viz(df_mer["KBCLUSTS"])
# Out:
# C:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 3 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# #### GaussianMixture

# %%
#Настройка параметров
gm = GaussianMixture(n_components=2, random_state=0).fit_predict(X)
#Заношу кластеризированные метки в набор данных
df_mer["GMCLUSTS"] = gm

viz(df_mer["GMCLUSTS"])

# %% [markdown]
# #### Результаты метрик

# %% [markdown]
# ##### Kmeans

# %%
#Использую метрику calinski_harabasz_score
print(sklearn.metrics.calinski_harabasz_score(X, df_mer["KMCLUSTS"]))
#Использую метрику davies_bouldin_score
print(sklearn.metrics.davies_bouldin_score(X, df_mer["KMCLUSTS"]))
# Out:
# 401790.65601221117
# 0.4350539754978302

# %% [markdown]
# ##### MiniBatchKmeans

# %%
#Использую метрику calinski_harabasz_score
print(sklearn.metrics.calinski_harabasz_score(X, df_mer["KBCLUSTS"]))
#Использую метрику davies_bouldin_score
print(sklearn.metrics.davies_bouldin_score(X, df_mer["KBCLUSTS"]))
# Out:
# 401790.65601221117
# 0.4350539754978302

# %% [markdown]
# ##### GussianMixture

# %%
#Использую метрику calinski_harabasz_score
print(sklearn.metrics.calinski_harabasz_score(X, df_mer["GMCLUSTS"]))
#Использую метрику davies_bouldin_score
print(sklearn.metrics.davies_bouldin_score(X, df_mer["GMCLUSTS"]))
# Out:
# 256289.56427777198
# 0.5726395717016782

# %% [markdown]
# #### Решение
# По результатам метрик и визуализаций, лучшим алгоритмом является GussianMixture

# %%
# Удаление ненужных атрибутов с кластерами
df_mer.drop(columns=['KMCLUSTS', 'KBCLUSTS'], axis=1, inplace=True)

# %% [markdown]
# ### 1.6 Подготовка отчета

# %% [markdown]
# * 1.1 - На основании файла Data2.csv построен исходный набор данных. Набор данных преобразован в единый файл формата .csv. Набор был дополнен доп данными, т.к. они могут были полезны для дальнейшего исследования.
#
# * 1.3 - Был предобработан набор данных на содержание пропусков и аномалий .
# * 1.4 - Были добавленны данные, которые могут быть полезны для дальнейшей работе.
# * 1.5- Выполнина кластеризация данных по сходству покупателей несколькими способами (не менее трех). Выбрана метрика оценки качества кластеризации. Обоснован выбор методов и приемов. Выполнен визуальный анализ кластерных структур и оценки качества кластеризации. Определён лучший алгоритм кластеризации на основе выбранной метрики.

# %%
df_mer.to_csv('output.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# --------------

# %% [markdown]
# # Модуль 2

# %% [markdown]
# -------------

# %%
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# Алгоритмы классификации
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# Игнорирование ошибок будущих версий
from warnings import simplefilter
simplefilter(action='ignore', category=FutureWarning)

# %%
df = pd.read_csv('output.csv')

# %% [markdown]
# ### 2.1 Разведочный анализ

# %%
df.head()
# Out:
#    AGE  GENDER  EDUCATION_LEVEL  MARITAL_STATUS  INCOME_MAIN_AMT  REG_CODE
# 0   35       2                3               3          87000.0       9.0  \
# 1   35       2                3               3          87000.0       9.0
# 2   35       2                3               3          87000.0       9.0
# 3   35       2                3               3          87000.0       9.0
# 4   35       2                3               3          87000.0       9.0
#
#    INCOME_MAIN_AMT_EUR  INCOME_MAIN_AMT_CNY  GMCLUSTS
# 0               1087.5          7909.090909         1
# 1               1087.5          7909.090909         1
# 2               1087.5          7909.090909         1
# 3               1087.5          7909.090909         1
# 4               1087.5          7909.090909         1

# %%
#Лист с признаками которые не будут учитываться при визуализации (Не категориальные)
skip = ['AGE', 'INCOME_MAIN_AMT', 'INCOME_MAIN_AMT_EUR']
#Не категориальные признаки
for i in skip:
    if type(df[i].iloc[2]) == np.int64 or type(df[i].iloc[2]) == np.float64:
        sns.displot(df, x=i, kind="kde", fill=True)

# %%
#Категориальные признаки
for i in df.columns:
    if i not in skip and i != 'REG_CODE':
        sns.catplot(x=i, kind='count', palette='ch:25', height=2, aspect=5, data=df)
        plt.show()

# %% [markdown]
# REG_CODE плохо визуализировался, так что его можно вывести отдельно

# %%
sns.catplot(x='REG_CODE', kind='count', palette='ch:25', height=4, aspect=5, data=df)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### 2.2 Разбиение выборки

# %%
df.head()
# Out:
#    AGE  GENDER  EDUCATION_LEVEL  MARITAL_STATUS  INCOME_MAIN_AMT  REG_CODE
# 0   35       2                3               3          87000.0       9.0  \
# 1   35       2                3               3          87000.0       9.0
# 2   35       2                3               3          87000.0       9.0
# 3   35       2                3               3          87000.0       9.0
# 4   35       2                3               3          87000.0       9.0
#
#    INCOME_MAIN_AMT_EUR  INCOME_MAIN_AMT_CNY  GMCLUSTS
# 0               1087.5          7909.090909         1
# 1               1087.5          7909.090909         1
# 2               1087.5          7909.090909         1
# 3               1087.5          7909.090909         1
# 4               1087.5          7909.090909         1

# %% [markdown]
# Система рекомендаций будет определять категорию принадлежности, то есть порекомендовать пользователю товар для мужчин или для женщин

# %% [markdown]
# #### MinMaxScaler
# Преобразование характеристик путем масштабирования каждой характеристики в заданном диапазоне. Этот оценщик масштабирует и переводит каждый признак в отдельности таким образом,чтобы он находился в заданном диапазоне на обучающем множестве,например,между нулем и единицей.

# %%
#обьявляю MinMaxScaler
scaler = MinMaxScaler()
#преобразую данные
X = scaler.fit_transform(X)

# %%
#Помещу их в переменную X
X = df[["AGE", "EDUCATION_LEVEL", "REG_CODE", "GMCLUSTS"]]
y = df["GENDER"]

# %%
#Разделение данных на обучающий и тестовый набор
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# #### Реализация моделей

# %% [markdown]
# #### KNN

# %%
#Объявление классификатор
neigh = KNeighborsClassifier()
#Обучение классификатора
neigh.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# #### GaussianNB

# %%
#Объявление классификатор
gnb = GaussianNB()
#Обучение классификатора
gnb.fit(X_train, y_train)
GaussianNB()
# Out:
# GaussianNB()

# %% [markdown]
# #### LogisticRegression

# %%
#Объявление классификатор
clf = LogisticRegression()
#Обучение классификатора
clf.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# #### Метрики
# Теперь посмотрю на результаты метрик, я буду рассматривать метрики - f1 и accuracy sore, f так же f1 по macro avg

# %% [markdown]
# #### KNN

# %%
#Вывожу результаты метрик при помощи classification_report
print(classification_report(y_test, neigh.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     21032
#            2       1.00      1.00      1.00     15408
#
#     accuracy                           1.00     36440
#    macro avg       1.00      1.00      1.00     36440
# weighted avg       1.00      1.00      1.00     36440

# %% [markdown]
# #### GaussianNB

# %%
#Вывожу результаты метрик при помощи classification_report
print(classification_report(y_test, gnb.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     21032
#            2       1.00      1.00      1.00     15408
#
#     accuracy                           1.00     36440
#    macro avg       1.00      1.00      1.00     36440
# weighted avg       1.00      1.00      1.00     36440

# %% [markdown]
# #### LogisticRegression

# %%
#Вывожу результаты метрик при помощи classification_report
print(classification_report(y_test, clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     21032
#            2       1.00      1.00      1.00     15408
#
#     accuracy                           1.00     36440
#    macro avg       1.00      1.00      1.00     36440
# weighted avg       1.00      1.00      1.00     36440

# %% [markdown]
# #### Решение
# По итогам метрик, остановлюсь на алгоритме KNN, так как он имеет самые высокие показатели, по f1 accuracy показал 0.99, и f1 macro avg 0.99. В то время как остальные алгоритмы показали 1, что может оказаться переобучением.

# %% [markdown]
# ### 2.3 Оптимизация модели

# %% [markdown]
# #### Генерация новых данных

# %%
df.head()
# Out:
#    AGE  GENDER  EDUCATION_LEVEL  MARITAL_STATUS  INCOME_MAIN_AMT  REG_CODE
# 0   35       2                3               3          87000.0       9.0  \
# 1   35       2                3               3          87000.0       9.0
# 2   35       2                3               3          87000.0       9.0
# 3   35       2                3               3          87000.0       9.0
# 4   35       2                3               3          87000.0       9.0
#
#    INCOME_MAIN_AMT_EUR  INCOME_MAIN_AMT_CNY  GMCLUSTS
# 0               1087.5          7909.090909         1
# 1               1087.5          7909.090909         1
# 2               1087.5          7909.090909         1
# 3               1087.5          7909.090909         1
# 4               1087.5          7909.090909         1

# %% [markdown]
# В данном случае можно воспользоваться уже созданным нами атрибутом INCOME_MAIN_AMT_USD

# %%
#обьявляю MinMaxScaler
scaler = MinMaxScaler()
#преобразую данные
X = scaler.fit_transform(X)

# %%
#Помещу их в переменную X
X = df[["AGE", "EDUCATION_LEVEL", "REG_CODE", "GMCLUSTS", 'INCOME_MAIN_AMT_EUR']]
y = df["GENDER"]

# %%
#Разделение данных на обучающий и тестовый набор
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# #### Реализация моделей

# %%
#Объявление классификатор
neigh2 = KNeighborsClassifier(n_neighbors=2, leaf_size=10, p=3, n_jobs=-1)
#Обучение классификатора
neigh2.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(leaf_size=10, n_jobs=-1, n_neighbors=2, p=3)

# %% [markdown]
# #### Метрика

# %%
#Вывожу результаты метрик при помощи classification_report
print(classification_report(y_test, neigh2.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     21032
#            2       1.00      1.00      1.00     15408
#
#     accuracy                           1.00     36440
#    macro avg       1.00      1.00      1.00     36440
# weighted avg       1.00      1.00      1.00     36440

# %% [markdown]
# Модель стала хуже, так что для дальнейшего использования лучше будет оставить первую версию

# %% [markdown]
# ## Гиперпараметры по умолчанию

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
base_pred = model.predict(X_test)
base_pred
# Out:
# array([2, 2, 1, ..., 1, 1, 2], dtype=int64)

# %% [markdown]
# ## Визуализация дерева

# %%
from sklearn.tree import plot_tree

# %%
plt.figure(figsize=(12,8))
plot_tree(model);

# %%
plt.figure(figsize=(12,8),dpi=150)
plot_tree(model,filled=True,feature_names=X.columns)
# Out:
# [Text(0.5, 0.75, 'GMCLUSTS <= 0.5\ngini = 0.488\nsamples = 85025\nvalue = [49074, 35951]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 49074\nvalue = [49074, 0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 35951\nvalue = [0, 35951]')]

# %% [markdown]
# ## Результаты модели
#
# Чтобы поэкспериментировать с гиперпараметрами, давайте создадим функцию, которая возвращает результаты классификации, а также рисует дерево.

# %%
def report_model(model):
    model_preds = model.predict(X_test)
    print(classification_report(y_test,model_preds))
    print('\n')
    plt.figure(figsize=(12,8),dpi=150)
    plot_tree(model,filled=True,feature_names=X.columns);

# %% [markdown]
# ## Гиперпараметры
#
# ### Гиперпараметр "Max Depth"

# %%
pruned_tree = DecisionTreeClassifier(max_depth=10)
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     21032
#            2       1.00      1.00      1.00     15408
#
#     accuracy                           1.00     36440
#    macro avg       1.00      1.00      1.00     36440
# weighted avg       1.00      1.00      1.00     36440

# %% [markdown]
# ## Гиперпараметр "Max Leaf Nodes"

# %%
pruned_tree = DecisionTreeClassifier(max_leaf_nodes=4)
pruned_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_leaf_nodes=4)

# %%
report_model(pruned_tree)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     21032
#            2       1.00      1.00      1.00     15408
#
#     accuracy                           1.00     36440
#    macro avg       1.00      1.00      1.00     36440
# weighted avg       1.00      1.00      1.00     36440

# %% [markdown]
# ## Гиперпараметр "Criterion"

# %%
entropy_tree = DecisionTreeClassifier(criterion='entropy')
entropy_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
report_model(entropy_tree)
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00     21032
#            2       1.00      1.00      1.00     15408
#
#     accuracy                           1.00     36440
#    macro avg       1.00      1.00      1.00     36440
# weighted avg       1.00      1.00      1.00     36440

# %% [markdown]
# Была выполненна

# %% [markdown]
# #### Сохранение лучшей модели

# %% [markdown]
# Ниже представлен код сохранения модели

# %%
import pickle
filename = 'finalized_model.sav'
pickle.dump(neigh, open(filename, 'wb'))

# %% [markdown]
# Так выглядит загрузка модели

# %%
# load the model from disk
#loaded_model = pickle.load(open(filename, 'rb'))

# %% [markdown]
# ### 2.4 Подготовка отчета

# %% [markdown]
# * 1 - Проведён анализ плотности распределения атрибутов и целевой переменной набора данных. Была произведена интерпретация полученных результатов.
# Используя программные средства, визуализуализирована зависимость атрибутов в наборе данных.  Визуализация отражает влияние атрибутов на категории, суммы покупок и предпочтения пользователей по покупкам. Произведены расчеты зависимостей по выбранным алгоритмам. Приведите интерпретацию полученных результатов.
#
# * 2 - Выполнино разбиение полученной выборки на обучающую и тестовую. Проведино обучение моделей, основанных на различных алгоритмах. Сделанно предсказание категории товара или услуги на тестовой выборке. Выполнена оценка моделей разной степени сложности в соответствии с выбранной метрикой. Определина модель, показавшее лучшее качество.
#
# * 3 - Выполнина настройка полученной модели уменьшив вычислительную сложность модели. Путём преобразования набора данных, добились более точной работы выбранной модели. Полученная модель была оптимизированна под решаемую задачу, настроили гиперпараметры.

# %%
df.to_csv('output2.csv', index=False, encoding='utf-8-sig')
